# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('exchange rate.csv')
df
# Out:
#                   Rate Date  Currency Rate Year  Rate Month  Buying Rate  \
# 4/18/2023         US DOLLAR      2023     April    460.0300     460.5300
# 4/18/2023   POUNDS STERLING      2023     April    572.5993     573.2217
# 4/18/2023              EURO      2023     April    504.6529     505.2014
# 4/18/2023       SWISS FRANC      2023     April    512.9111     513.4686
# 4/18/2023               YEN      2023     April      3.4351       3.4388
# ...                     ...       ...       ...         ...          ...
# 12/10/2001              CFA      2001  December      0.1514       0.1521
# 12/10/2001             EURO      2001  December     99.3787      99.8230
# 12/10/2001             WAUA      2001  December    138.8876     139.5084
# 12/10/2001        US DOLLAR      2001  December    111.8500     112.3500
# 12/10/2001              YEN      2001  December      0.8881       0.8921
#
#             Central Rate  Selling Rate
# 4/18/2023       461.0300           NaN
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#             index        Rate Date  Currency Rate Year  Rate Month  \
# 0       4/18/2023        US DOLLAR      2023     April    460.0300
# 1       4/18/2023  POUNDS STERLING      2023     April    572.5993
# 2       4/18/2023             EURO      2023     April    504.6529
# 3       4/18/2023      SWISS FRANC      2023     April    512.9111
# 4       4/18/2023              YEN      2023     April      3.4351
# ...           ...              ...       ...       ...         ...
# 51936  12/10/2001              CFA      2001  December      0.1514
# 51937  12/10/2001             EURO      2001  December     99.3787
# 51938  12/10/2001             WAUA      2001  December    138.8876
# 51939  12/10/2001        US DOLLAR      2001  December    111.8500
# 51940  12/10/2001              YEN      2001  December      0.8881
#
#        Buying Rate  Central Rate  Selling Rate
# 0         460.5300      461.0300           NaN
# 1         573.2217      573.8440           NaN
# ...

# %%
df.columns
# Out:
# Index(['index', 'Rate Date', 'Currency', 'Rate Year', 'Rate Month',
#        'Buying Rate', 'Central Rate', 'Selling Rate'],
#       dtype='object')

# %%
df.rename({'index': 'Date', 'Rate Date': 'Currency', 'Currency': ' Year', 'Rate Year': ' Month', 'Rate Month': 'Buying Rate',
       'Buying Rate': 'Central Rate' , 'Central Rate': 'Selling Rate', 'Selling Rate':'unknown'}, axis =1, inplace=True)

# %%
df.head()
# Out:
#         Date         Currency   Year  Month  Buying Rate  Central Rate  \
# 0  4/18/2023        US DOLLAR   2023  April     460.0300      460.5300
# 1  4/18/2023  POUNDS STERLING   2023  April     572.5993      573.2217
# 2  4/18/2023             EURO   2023  April     504.6529      505.2014
# 3  4/18/2023      SWISS FRANC   2023  April     512.9111      513.4686
# 4  4/18/2023              YEN   2023  April       3.4351        3.4388
#
#    Selling Rate  unknown
# 0      461.0300      NaN
# 1      573.8440      NaN
# 2      505.7499      NaN
# 3      514.0261      NaN
# 4        3.4426      NaN

# %%
df.drop('unknown', axis =1, inplace=True)

# %%
df.head()
# Out:
#         Date         Currency   Year  Month  Buying Rate  Central Rate  \
# 0  4/18/2023        US DOLLAR   2023  April     460.0300      460.5300
# 1  4/18/2023  POUNDS STERLING   2023  April     572.5993      573.2217
# 2  4/18/2023             EURO   2023  April     504.6529      505.2014
# 3  4/18/2023      SWISS FRANC   2023  April     512.9111      513.4686
# 4  4/18/2023              YEN   2023  April       3.4351        3.4388
#
#    Selling Rate
# 0      461.0300
# 1      573.8440
# 2      505.7499
# 3      514.0261
# 4        3.4426

# %%
df['Currency'].unique()
# Out:
# array(['US DOLLAR', 'POUNDS STERLING', 'EURO', 'SWISS FRANC', 'YEN',
#        'CFA', 'WAUA', 'YUAN/RENMINBI', 'RIYAL', 'SOUTH AFRICAN RAND',
#        'DANISH KRONA', 'SDR', 'POUND STERLING', 'DANISH KRONER',
#        'JAPANESE YEN', 'US DOLLAR ', 'YEN ', 'CFA ', 'WAUA ', 'SDR ',
#        'EURO\t', 'EURO ', 'RIYAL ', 'SWISS FRANC\t', 'SDR\t', 'NAIRA',
#        'POESO'], dtype=object)

# %%
df.replace({'US DOLLAR': 'USD', 'POUNDS STERLING': 'POUNDS',
        'YUAN/RENMINBI':'YUAN', 
       'DANISH KRONER': 'DANISH KRONA', 'POUND STERLING': 'POUNDS',
       'JAPANESE YEN': 'YEN', 'YEN ': 'YEN', 'CFA ':'CFA', 'WAUA ':'WAUA', 'SDR ':'SDR',
       'EURO\t': 'EURO', 'EURO ':'EURO', 'RIYAL ':'RIYAL', 'SWISS FRANC\t': 'SWISS FRANC', 'SDR\t': 'SDR'}, inplace = True)

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.head
# Out:
# <bound method NDFrame.head of             Date     Currency   Year     Month  Buying Rate  Central Rate  \
# 0     2023-04-18          USD   2023     April     460.0300      460.5300
# 1     2023-04-18       POUNDS   2023     April     572.5993      573.2217
# 2     2023-04-18         EURO   2023     April     504.6529      505.2014
# 3     2023-04-18  SWISS FRANC   2023     April     512.9111      513.4686
# 4     2023-04-18          YEN   2023     April       3.4351        3.4388
# ...          ...          ...    ...       ...          ...           ...
# 51936 2001-12-10          CFA   2001  December       0.1514        0.1521
# 51937 2001-12-10         EURO   2001  December      99.3787       99.8230
# 51938 2001-12-10         WAUA   2001  December     138.8876      139.5084
# 51939 2001-12-10          USD   2001  December     111.8500      112.3500
# 51940 2001-12-10          YEN   2001  December       0.8881        0.8921
#
#        Selling Rate
# 0          461.0300
# ...

# %%
df.to_csv('rate.csv', index=False)

# %%
df2 = pd.read_csv('RealGDP.csv')
df2
# Out:
#        tyear    Period  Agriculture  CropProduction  Livestock  Forestry  \
# 1981  Annual   2364.37      1854.76          341.41      77.90     90.30
# 1982  Annual   2425.96      1897.08          361.12      73.91     93.86
# 1983  Annual   2409.08      1842.70          393.13      75.28     97.96
# 1984  Annual   2303.51      1759.12          399.69      76.69     68.01
# 1985  Annual   2731.06      2180.91          428.10      78.08     43.97
# ...      ...       ...          ...             ...        ...       ...
# 2022      Q1   3879.73      3391.63          318.50      44.14    125.46
# 2022      Q2   4017.42      3595.83          282.02      51.28     88.30
# 2022      Q3   5625.36      5200.73          302.90      48.07     73.67
# 2022      Q4   5568.55      5072.56          344.31      52.87     98.81
# 2022  Annual  19091.07     17260.75         1247.72     196.36    386.24
#
#        Fishing  Industry  MiningAndQuarrying  CrudePetroleumAndNaturalGas  \
# ...

# %%
df2.reset_index(inplace=True)
df2.columns
# Out:
# Index(['index', 'tyear', 'Period', 'Agriculture', 'CropProduction',
#        'Livestock', 'Forestry', 'Fishing', 'Industry', 'MiningAndQuarrying',
#        'CrudePetroleumAndNaturalGas', 'CoalMining', 'MetalOres',
#        'QuarryingAndOtherMinerals', 'Manufacturing', 'OilRefining', 'Cement',
#        'FoodBeverageAndTobacco', 'TextileApparelAndFootwear',
#        'WoodAndWoodProducts', 'PulpPaperAndPaperProducts',
#        'ChemicalAndPharmaceuticalProducts', 'NonMetallicProducts',
#        'PlasticAndRubberProducts', 'ElectricalAndElectronics',
#        'BasicMetalIronAndSteel', 'MotorVehiclesAndAssembly',
#        'OtherManufacturing', 'ElectricityGasSteamAndAirCon',
#        'WaterSupplySewageWaste', 'Construction', 'Services', 'Trade',
#        'AccommodationAndFoodServices', 'TransportationAndStorage',
#        'RoadTransport', 'RailTransportAndPipelines', 'WaterTransport',
#        'AirTransport', 'TransportServices', 'PostAndCourierServices',
# ...

# %%
df2.rename({'index': 'Year', 'tyear':'Period', 'Period': 'Agriculture', 'Agriculture':'CropProduction', 'CropProduction': 'Livestock',
       'Livestock':'Forestry', 'Forestry':'Fishing', 'Fishing':'Industry', 'Industry':'MiningandQuarrying', 'MiningAndQuarrying':'CrudePetroleumAndNaturalGas',
       'CrudePetroleumAndNaturalGas': 'CoalMining', 'CoalMining':'MetalOres', 'MetalOres':'QuarryingAndOtherMinerals',
       'QuarryingAndOtherMinerals':'Manufacturing', 'Manufacturing':'OilRefining', 'OilRefining':'Cement', 'Cement':'FoodBeverageAndTobacco',
       'FoodBeverageAndTobacco':'TextileApparelAndFootwear', 'TextileApparelAndFootwear':'WoodAndWoodProducts',
       'WoodAndWoodProducts':'PulpPaperAndPaperProducts', 'PulpPaperAndPaperProducts':'ChemicalAndPharmaceuticalProducts',
       'ChemicalAndPharmaceuticalProducts':'NonMetallicProducts', 'NonMetallicProducts':'PlasticAndRubberProducts',
       'PlasticAndRubberProducts':'ElectricalAndElectronics', 'ElectricalAndElectronics':'BasicMetalIronAndSteel',
       'BasicMetalIronAndSteel':'MotorVehiclesAndAssembly', 'MotorVehiclesAndAssembly':'OtherManufacturing',
       'OtherManufacturing':'ElectricityGasSteamAndAirCon', 'ElectricityGasSteamAndAirCon':'WaterSupplySewageWaste',
       'WaterSupplySewageWaste':'Construction', 'Construction':'Services', 'Services':'Trade', 'Trade':'AccommodationAndFoodServices',
       'AccommodationAndFoodServices':'TransportationAndStorage', 'TransportationAndStorage':'RoadTransport',
       'RoadTransport':'RailTransportAndPipelines', 'RailTransportAndPipelines':'WaterTransport', 'WaterTransport':'AirTransport',
       'AirTransport':'TransportServices', 'TransportServices':'PostAndCourierServices', 'PostAndCourierServices':'InformationAndCommunication',
       'InformationAndCommunication':'Publishing', 'Publishing':'MotionPicturesSoundRecordingAndMusicProduction',
       'MotionPicturesSoundRecordingAndMusicProduction':'Broadcasting', 'Broadcasting':'ArtsEntertainmentAndRecreation','ArtsEntertainmentAndRecreation':'FinanceAndInsurance', 'FinanceAndInsurance':'FinancialInstitutions',
       'FinancialInstitutions':'Insurance', 'Insurance':'RealEstate', 'RealEstate':'ProfessionalScientificAndTechnicalServices',
       'ProfessionalScientificAndTechnicalServices':'AdministrativeAndSupportServicesBusinessServices',
       'AdministrativeAndSupportServicesBusinessServices':'PublicAdministration',
       'PublicAdministration':'Education', 'Education':'HumanHealthAndSocialServices', 'HumanHealthAndSocialServices':'OtherServices',
       'OtherServices': 'GDP at 2010 Constant Basic Prices', 'GDP at 2010 Constant Basic Prices':'NetTaxesOnProducts',
       'NetTaxesOnProducts':'GDP at 2010 Constant Market Prices', 'GDP at 2010 Constant Market Prices':'UNKNOWN'}, inplace=True, axis=1)
df2
# Out:
#     Year  Period  Agriculture  CropProduction  Livestock  Forestry  Fishing  \
# 0   1981  Annual      2364.37         1854.76     341.41     77.90    90.30
# 1   1982  Annual      2425.96         1897.08     361.12     73.91    93.86
# 2   1983  Annual      2409.08         1842.70     393.13     75.28    97.96
# 3   1984  Annual      2303.51         1759.12     399.69     76.69    68.01
# 4   1985  Annual      2731.06         2180.91     428.10     78.08    43.97
# ..   ...     ...          ...             ...        ...       ...      ...
# 89  2022      Q1      3879.73         3391.63     318.50     44.14   125.46
# 90  2022      Q2      4017.42         3595.83     282.02     51.28    88.30
# 91  2022      Q3      5625.36         5200.73     302.90     48.07    73.67
# 92  2022      Q4      5568.55         5072.56     344.31     52.87    98.81
# 93  2022  Annual     19091.07        17260.75    1247.72    196.36   386.24
#
# ...

# %%
df2.drop('UNKNOWN', axis=1, inplace=True)

# %%
df2
# Out:
#     Year  Period  Agriculture  CropProduction  Livestock  Forestry  Fishing  \
# 0   1981  Annual      2364.37         1854.76     341.41     77.90    90.30
# 1   1982  Annual      2425.96         1897.08     361.12     73.91    93.86
# 2   1983  Annual      2409.08         1842.70     393.13     75.28    97.96
# 3   1984  Annual      2303.51         1759.12     399.69     76.69    68.01
# 4   1985  Annual      2731.06         2180.91     428.10     78.08    43.97
# ..   ...     ...          ...             ...        ...       ...      ...
# 89  2022      Q1      3879.73         3391.63     318.50     44.14   125.46
# 90  2022      Q2      4017.42         3595.83     282.02     51.28    88.30
# 91  2022      Q3      5625.36         5200.73     302.90     48.07    73.67
# 92  2022      Q4      5568.55         5072.56     344.31     52.87    98.81
# 93  2022  Annual     19091.07        17260.75    1247.72    196.36   386.24
#
# ...

# %%
df2.to_csv('GDP.csv', index=False)

# %%
#EXERCISE
df3 = pd.read_excel('Telecom Churn Rate Dataset.xlsx')
df3
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df3.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# numAdminTickets     0
# numTechTickets      0
# Churn               0
# dtype: int64

# %%
print('the average tenure of customers is', round(np.mean(df3['tenure']),2)) #outcome will round up to 2 #numpy
# Out:
# the average tenure of customers is 32.37

# %%
print ('the average tenure of customers is', round(df3['tenure'].apply('mean')))#pandas
# Out:
# the average tenure of customers is 32

# %%
print (f'''the distribution of gender are as follows
 {df3['gender'].value_counts()}
''')
# Out:
# the distribution of gender are as follows
#  Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
df3['SeniorCitizen'].value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
df3['Partner'].value_counts()/df3['Partner'].value_counts().sum()*100
# Out:
# No     51.69672
# Yes    48.30328
# Name: Partner, dtype: float64

# %%
print (f'''the number of customers that have dependents are as follows
 {df3['Dependents'].value_counts()}
''')
# Out:
# the number of customers that have dependents are as follows
#  No     4933
# Yes    2110
# Name: Dependents, dtype: int64

# %%
df3['InternetService'].mode()
# Out:
# 0    Fiber optic
# Name: InternetService, dtype: object

# %%
for customer in 'OnlineSecurity' and 'OnlineBackup':
    where: 'OnlineSecurity' == 'Yes' and 'OnlineBackup' == 'Yes'
print (f'''the number of customers that have online security and backup {df3['OnlineSecurity'].value_counts().sum() + df3['OnlineBackup'].value_counts().sum()}''')
# Out:
# the number of customers that have online security and backup 14086

# %%
df3['OnlineBackup'].mode()
# Out:
# 0    No
# Name: OnlineBackup, dtype: object

# %%
df3['OnlineBackup'].value_counts()
# Out:
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64

# %%
df3 ['MonthlyCharges'] .apply('mean')
# Out:
# 64.76169246059922

# %%
df3['TotalCharges'] .apply('mean'),2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [118], in <cell line: 1>()
# ----> 1 df3['TotalCharges'] .apply('mean'),2
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1080, in SeriesApply.apply(self)
#    1076     return self.apply_multiple()
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
# -> 1080     return self.apply_str()
# ...
